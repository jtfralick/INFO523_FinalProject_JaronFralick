# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import plotly.express as px
from sklearn.decomposition import PCA

# %%
class PCA:
    def __init__(self, n_components):
        self.n_components = n_components
        self.components = None
        self.mean = None

    def fit(self, X):
        # Mean centering
        self.mean = np.mean(X, axis=0)
        X = X - self.mean

        # covariance, function needs samples as columns
        cov = np.cov(X.T)

        # eigenvalues, eigenvectors
        eigenvalues, eigenvectors = np.linalg.eig(cov)

        # -> eigenvector v = [:,i] column vector, transpose for easier calculations
        # sort eigenvectors
        eigenvectors = eigenvectors.T
        idxs = np.argsort(eigenvalues)[::-1]
        eigenvalues = eigenvalues[idxs]
        eigenvectors = eigenvectors[idxs]

        # store first n eigenvectors
        self.components = eigenvectors[0 : self.n_components]
        

    def transform(self, X):
        # project data
        #X = X - self.mean
        return np.dot(X, self.components.T)

# %% [markdown]
# # Iris Dataset

# %%
#2-D Plotly

# data = datasets.load_digits()
iris = datasets.load_iris()
X = iris.data
y = iris.target

y_label = []

for i in y:
  if i == 0:
    y_label.append('Setosa')
  elif i == 1:
    y_label.append('Versicolor')
  else:
    y_label.append('Virginica')

Species = pd.DataFrame(y_label,columns=['Species'])



# Project the data onto the 2 primary principal components
pca = PCA(2)
pca.fit(X)
X_projected = pca.transform(X)


print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2'])
X_y_df = df_scores = pd.concat([X_df, Species], axis=1)
# Out:
# Shape of X: (150, 4)
# Shape of transformed X: (150, 2)

# %%
fig = px.scatter(X_y_df, x='PC1', y='PC2',color='Species')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b5487205-bf03-4796-9fee-20e33b6c25df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5487205-bf03-4796-9fee-20e33b6c25df")) {
#                     Plotly.newPlot(
#                         'b5487205-bf03-4796-9fee-20e33b6c25df',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Species=Setosa<br>PC1=%{x}<br>PC2=%{y}", "legendgroup": "Species=Setosa", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Species=Setosa", "showlegend": true, "type": "scatter", "x": [2.818239506639467, 2.788223445314678, 2.613374563549707, 2.757022276967594, 2.7736485960544734, 3.2215054997645107, 2.6818273818683944, 2.876220159462371, 2.6159824008284507, 2.8296093347880493, 2.995418041957148, 2.8896099017002808, 2.716255866420986, 2.278561388743351, 2.8576147426669736, 3.11632609907787, 2.8788372573845766, 2.8540684263546217, 3.302544808991423, 2.9143787327302344, 3.192108917366485, 2.9586599038518466, 2.286425716960392, 3.199631950382796, 3.146611083485231, 2.995696225683182, 3.0335450594876643, 2.9400452264129875, 2.862830417224461, 2.8703757453346577, 2.914966655919651, 3.092432635606828, 2.8535027982590915, 2.9036283835084165, 2.8654382545032044, 2.636123480490334, 2.8771270827586313, 2.7016810171607815, 2.5218630888270104, 2.9123588186409073, 2.7322627065811016, 2.6529964275659, 2.5049585860140966, 3.0967506475115174, 3.2928758948253236, 2.7879137058512957, 2.9642168736100634, 2.6629029649661535, 2.9592793827786106, 2.7990053502738443], "xaxis": "x", "y": [-5.646349823412795, -5.149951351762913, -5.182003150742136, -5.008653597575777, -5.653707089762613, -6.06828302589061, -5.2374911922991245, -5.490337536526022, -4.748640822640989, -5.213178330953577, -5.972021475476267, -5.341682515989069, -5.091840576625975, -4.815557989821311, -6.505717213265268, -6.665014907228347, -6.137632091008952, -5.638801721421048, -6.199791615789905, -5.84051288557697, -5.718298512481588, -5.759948640106723, -5.460420646366219, -5.425661431641793, -5.289670717150312, -5.180935696332425, -5.4579040662629446, -5.694671434261894, -5.638992557062976, -5.129991351903379, -5.12263408555356, -5.7378768410572665, -6.140316397124656, -6.420098336277051, -5.20563022896183, -5.396317048407774, -5.9263225982071175, -5.595596314625676, -4.838994232399078, -5.555996413654706, -5.59048011057195, -4.385992003186496, -4.985026519356084, -5.515824005757954, -5.763615718466882, -5.076744372642482, -5.830723721289131, -5.099007007333865, -5.906362598347583, -5.434658659327105], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Species=Versicolor<br>PC1=%{x}<br>PC2=%{y}", "legendgroup": "Species=Versicolor", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Species=Versicolor", "showlegend": true, "type": "scatter", "x": [6.787190821467354, 6.434853664921321, 6.966667454600397, 5.685682852567373, 6.590468390320669, 6.14403421686708, 6.59742579524145, 4.753242462779346, 6.546496958662439, 5.493619728526107, 4.994524248773677, 6.0140636900566005, 5.767341640721049, 6.4872996430798935, 5.328439760927235, 6.43022591355325, 6.16264889430594, 5.738470125926674, 6.447098860628816, 5.547592108907702, 6.618648309959052, 5.86025355060631, 6.800549007967916, 6.42409405505604, 6.217218458520414, 6.40253950578117, 6.834389569331091, 7.060167287675072, 6.3156557824265445, 5.196781354584694, 5.434238640540639, 5.312742660230501, 5.638793844167018, 6.882391568524514, 6.090371575948867, 6.3092234451094145, 6.723056015053356, 6.3174603683756025, 5.7483228124956955, 5.66877834975446, 5.967165421012782, 6.393180331078453, 5.7329131561684585, 4.797833373364339, 5.85934662731005, 5.834299612554061, 5.878580783675673, 6.144941140163341, 4.5958952676601665, 5.801365974487147], "xaxis": "x", "y": [-6.012113047295003, -5.645286215090323, -5.831215392136899, -4.498993565007062, -5.4015432520254105, -4.908705705259016, -5.610420846889223, -4.322061615645799, -5.55531447661609, -4.603870671822861, -4.060981386301299, -5.2229713413286545, -4.776916113147218, -5.202134722701338, -5.072098368125105, -5.794132071269205, -4.973982911103844, -4.993341810002778, -4.783807026047927, -4.74311819935583, -5.242335724632907, -5.2580275451716805, -4. ...
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar

# %%
# Testing 3-D Plotly

# data = datasets.load_digits()
iris = datasets.load_iris()
X = iris.data
y = iris.target

y_label = []

for i in y:
  if i == 0:
    y_label.append('Setosa')
  elif i == 1:
    y_label.append('Versicolor')
  else:
    y_label.append('Virginica')

Species = pd.DataFrame(y_label,columns=['Species'])

# Project the data onto the 2 primary principal components
pca = PCA(3)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2','PC3'])
X_y_df = df_scores = pd.concat([X_df, Species], axis=1)
# Out:
# Shape of X: (150, 4)
# Shape of transformed X: (150, 3)

# %%
fig = px.scatter_3d(X_y_df, x='PC1', y='PC2', z='PC3',color='Species')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id
}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Species=Versicolor<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}", "legendgroup": "Species=Versicolor", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Species=Versicolor", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [6.787190821467354, 6.434853664921321, 6.966667454600397, 5.685682852567373, 6.590468390320669, 6.14403421686708, 6.59742579524145, 4.753242462779346, 6.546496958662439, 5.493619728526107, 4.994524248773677, 6.0140636900566005, 5.767341640721049, 6.4872996430798935, 5.328439760927235, 6.43022591355325, 6.16264889430594 ...

# %% [markdown]
# # Wine Dataset

# %%
#2-D Plotly

# data = datasets.load_digits()
wine = datasets.load_wine()
X = wine.data
y = wine.target


y_label = []

for i in y:
  if i == 0:
    y_label.append('Wine Type 1')
  elif i == 1:
    y_label.append('Wine Type 2')
  else:
    y_label.append('Wine Type 3')

WineType = pd.DataFrame(y_label,columns=['WineType'])

# Project the data onto the 2 primary principal components
pca = PCA(2)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2'])
X_y_df = df_scores = pd.concat([X_df, WineType], axis=1)
# Out:
# Shape of X: (178, 13)
# Shape of transformed X: (178, 2)

# %%
fig = px.scatter(X_y_df, x='PC1', y='PC2',color='WineType')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ef309ffb-3506-4a10-a083-30bbe3905d68" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef309ffb-3506-4a10-a083-30bbe3905d68")) {
#                     Plotly.newPlot(
#                         'ef309ffb-3506-4a10-a083-30bbe3905d68',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "WineType=Wine Type 1<br>PC1=%{x}<br>PC2=%{y}", "legendgroup": "WineType=Wine Type 1", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "WineType=Wine Type 1", "showlegend": true, "type": "scatter", "x": [-1067.0556874907402, -1051.59012786219, -1186.55384112004, -1481.7328475536153, -736.9212797068981, -1451.7238999405258, -1291.4642890693965, -1296.8945680432407, -1046.5295710034154, -1046.5422613382718, -1511.5724201440505, -1281.4359359348016, -1321.327118593968, -1151.4180664889006, -1548.5461020597754, -1311.7382862016211, -1281.8723588387163, -1131.8102992800789, -1681.6110957024093, -846.895885678764, -782.0863022046575, -771.6391457430749, -1036.5857384202084, -1016.4742207377951, -846.5125939755819, -831.9914521641456, -1196.418304425146, -1286.411873224181, -916.7031758074532, -1036.5009552840684, -1286.519160304994, -1516.5856470581903, -991.6434591046952, -1237.0939882480393, -1096.7237151996233, -921.5726656289, -881.7791317493952, -1106.51126737807, -1021.5371397242073, -762.1357103161693, -796.9223504527337, -1036.3768003717948, -1096.5880563832504, -681.6780528167011, -886.7197180862457, -1081.7475140319702, -1066.6045566694424, -986.6041932815262, -1061.6126235906434, -1261.6804562240316, -1151.4317253617771, -1266.4216714682752, -1191.7591194977367, -1376.7787791879164, -1061.890320878436, -1121.8259994251835, -971.9098145607542, -1271.5655595994197, -1286.6748055257467], "xaxis": "x", "y": [-108.51625428742896, -81.659405869825, -80.48681410344888, -87.21685258496109, -105.5141181612493, -86.69196487863566, -73.50515691129209, -98.47355593644743, -78.84396571748067, -79.92258061532725, -78.6898063265902, -72.73648978241758, -66.01910922281785, -70.92148833429184, -74.90567636129968, -89.2389522169752, -97.82892578655141, -95.50154337045187, -78.66964511314556, -101.41678296619128, -112.59208005064153, -88.84159663915408, -83.06108180322394, -77.45341953948312, -81.52827749070053, -109.91574510284833, -72.22679230212965, -71.63577748786541, -91.2794345160386, -78.06439200387322, -78.81138473195074, -79.64422617824897, -86.88020862527415, -110.58944859612959, -91.06220370188717, -84.23120190311207, -94.79685312823841, -78.86613943476492, -80.29904924513009, -114.87095570063815, -103.34607331341118, -72.13900501767179, -81.9806974644334, -91.40895347119856, -91.75481191269301, -92.34345471113744, -83.53717861377203, -83.97260255159502, -84.71876038930131, -86.16036431767343, -71.9708207040823, -72.02656866434249, -90.28462559696229, -91.06526893368485, -99.63303706777121, -96.68832217920435, -101.24101596462596, -79.92749829697604, -85.6673434247873], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "WineType=Wine Type 2<br>PC1=%{x}<br>PC2=%{y}", "legendgroup": "WineType=Wine Type 2", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "WineType=Wine Type 2", "showlegend": true, "type": "scatter", "x": [-521.4600177503069, -681.6425862055546, -451.66827131138814, -631.5222356209457, -421.4335826076522, -356.7402217667537, -679.5869477601088, -503.28018422572455, -511.2512979102868, -751.7888641937836, -720.5265874722643, -871.6228465113664, -411.38858571479034, -473.396682323116, -987.2094647516647, -887.5867648427615, -429.61637930047414, -393.43245568866655, -501.85911075088785, -752.2643978583365, -464.6504605580374, -279.43335789353716, -715.3613689566474, -631.2023161929965, -516.3597198186807, -521.5394087826852, -451.64055646841786, -496.4463162743632, -563.3838508293109, -681.3119563583289, -626.0613818015986, -481.30737499975993, -451.3882935275173, -496.27882313103333, -291.470493260607, -346.64143411280776, -939.6761049753104, -627.2135304490622, -429.4044353981178, -661.4124156415053, -407.45180803545475, -711.5610936518054, -563.4189947087244, -439.61032159030776, -416.40341181990283, -673.3395704507772, -316.4829662799501, -511.2860111155467, -489.3 ...

# %%
# Testing 3-D Plotly

# data = datasets.load_digits()
wine = datasets.load_wine()
X = wine.data
y = wine.target

y_label = []

for i in y:
  if i == 0:
    y_label.append('Wine Type 1')
  elif i == 1:
    y_label.append('Wine Type 2')
  else:
    y_label.append('Wine Type 3')

WineType = pd.DataFrame(y_label,columns=['WineType'])

# Project the data onto the 2 primary principal components
pca = PCA(3)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2','PC3'])
X_y_df = df_scores = pd.concat([X_df, WineType], axis=1)
print(X_y_df)
# Out:
# Shape of X: (178, 13)
# Shape of transformed X: (178, 3)
#              PC1         PC2        PC3     WineType
# 0   -1067.055687 -108.516254  17.171375  Wine Type 1
# 1   -1051.590128  -81.659406  13.479274  Wine Type 1
# 2   -1186.553841  -80.486814  21.415332  Wine Type 1
.24101596462596, -79.92749829697604, -85.6673434247873], "z": [17.17137474306377, 13.479273952608198, 21.415332429243946, 21.219366463492143, 20.856531524330055, 19.35273411356265, 18.17516661858542, 20.261617027647024, 16.421134276739974, 18.74365412097067, 22.188399822545474, 20.17177420829374, 19.929494588946, 14.626969584641328, 17.255579540831718, 20.827620432447226, 22.77863679188922, 22.291854460584936, 22.235022207195296, 16.19836328630932, 16.268523298185528, 19.414948606959996, 18.248395639355873, 19.54369761629234, 20.689407108666764, 24.580945974461116, 19.08227499638221, 20.13741711853404, 20.405493855686945, 18.140611242213488, 25.470505727084454, 23.53207186100523, 18.621306719856264, 21.473735865473213, 20.749784443081605, 21.811901432063134, 16.582843372405026, 20.228908842410075, 17.267317077055413, 13.661558721767278, 16.940899320797477, 21.109045976200335, 17.463141078847773, 17.935566467810457, 18.108943605813277, 21.08586757703079, 18.308252067871628, 18.074782303695898, 21.158012974689246, 21.266002214378524, 16.049428905479697, 20.597542925059436, 17.076774580563693, 20.66004097540827, 18.29741008371399, 22.594155199536594, 17.91424440968713, 20.172821078705937, 20.071130936959353]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "WineType=Wine Type 2<br>PC1=%{x}<br>PC2 ...

# %% [markdown]
# # Heart Disease Dataset

# %%
from google.colab import files
uploaded = files.upload()
heart_data= pd.read_csv('heart.csv',header=None,skiprows=1)
# Out:
#      <input type="file" id="files-1fff493e-b3ad-4667-b3c4-4ab3d32cbeb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fff493e-b3ad-4667-b3c4-4ab3d32cbeb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart (1).csv

# %%
#2-D Plotly

X,y = heart_data.values[:,:-1], \
heart_data.values[:,-1]


y_label = []

for i in y:
  if i == 0:
    y_label.append('Healthy')
  else:
    y_label.append('Heart Disease')

HealthStatus = pd.DataFrame(y_label,columns=['HealthStatus'])

# Project the data onto the 2 primary principal components
pca = PCA(2)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2'])
X_y_df = df_scores = pd.concat([X_df, HealthStatus], axis=1)
print(X_y_df)
# Out:
# Shape of X: (303, 13)
# Shape of transformed X: (303, 2)
#             PC1         PC2   HealthStatus
# 0    240.826942 -124.566713  Heart Disease
# 1    255.784424 -167.311924  Heart Disease
# 2    210.144072 -151.077370  Heart Disease
# 3    242.149530 -155.878586  Heart Disease
# 4    360.073340 -143.315018  Heart Disease
# ..          ...         ...            ...
# 298  248.540166  -99.950381        Healthy
# 299  269.522294 -114.518834        Healthy
# 300  201.130475 -114.116752        Healthy
# 301  138.338306  -91.005366        Healthy
# 302  242.698145 -150.742951        Healthy
#
# [303 rows x 3 columns]

# %%
fig = px.scatter(X_y_df, x='PC1', y='PC2',color='HealthStatus')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2e1fec72-cc30-4959-aab9-4e52a37ebbc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e1fec72-cc30-4959-aab9-4e52a37ebbc3")) {
#                     Plotly.newPlot(
#                         '2e1fec72-cc30-4959-aab9-4e52a37ebbc3',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate":
434626315533, 227.7666579823663, 246.20710476298626, 348.56538918667417, 162.6809065653936, 181.4546267768569, 181.4546267768569], "xaxis": "x", "y": [-124.566712519935, -167.3119239555045, -151.0773702079431, -155.87858609625434, -143.3150181752474, -123.4366265565141, -130.47951118594312, -153.71511404516684, -134.87032772046823, -147.35062626726904, -136.61591407016513, -118.96928565823521, -149.86180781558812, -121.73711069347794, -137.69849407059655, -137.0862541206255, -151.69897755026585, -88.18080924144517, -148.48095941740917, -125.09585559686427, -137.103 ...

# %%
# Testing 3-D Plotly

# data = datasets.load_digits()
X,y = heart_data.values[:,:-1], \
heart_data.values[:,-1]


y_label = []

for i in y:
  if i == 0:
    y_label.append('Healthy')
  else:
    y_label.append('Heart Disease')

HealthStatus = pd.DataFrame(y_label,columns=['HealthStatus'])

# Project the data onto the 2 primary principal components
pca = PCA(3)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2','PC3'])
X_y_df = df_scores = pd.concat([X_df, HealthStatus], axis=1)
print(X_y_df)
# Out:
# Shape of X: (303, 13)
# Shape of transformed X: (303, 3)
#             PC1         PC2         PC3   HealthStatus
# 0    240.826942 -124.566713 -157.868050  Heart Disease
# 1    255.784424 -167.311924 -143.776054  Heart Disease
# 2    210.144072 -151.077370 -144.657617  Heart Disease
# 3    242.149530 -155.878586 -135.853991  Heart Disease
# 4    360.073340 -143.315018 -128.036596  Heart Disease
# ..          ...         ...         ...            ...
# 298  248.540166  -99.950381 -148.272664        Healthy
# 299  269.522294 -114.518834 -117.315377        Healthy
# 300  201.130475 -114.116752 -158.385015        Healthy
# 301  138.338306  -91.005366 -143.025942        Healthy
# 302  242.698145 -150.742951 -145.289475        Healthy
#
# [303 rows x 4 columns]

# %%
fig = px.scatter_3d(X_y_df, x='PC1', y='PC2', z='PC3',color='HealthStatus')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f9f272a-a9e2-45bb-9a86-99bd26ef388a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f9f272a-a9e2-45bb-9a86-99bd26ef388a")) {
#                     Plotly.newPlot(
#                         '4f9f272a-a9e2-45bb-9a86-99bd26ef388a',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "HealthStatus=Heart Disease<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}", "legendgroup": "HealthStatus=Heart Disease", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "HealthStatus=Heart Disease", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [240.8269416668127, 255.78442362586264, 210.14407243454295, 242.14953014551068, 360.07333983543907, 199.44708266521954, 301.1764416258075, 268.66034550923115, 207.65539035398243, 175.77797038814265, 246.15104912975994, 281.5202244545743, 272.342024195968, 217.28873068795957, 290.68297613903826, 225.09443473340508, 346.0693258225181, 234.46348916250724, 254.09674057563655, 246.81009602623948, 241.11314079640815, 239.14892155638566, 232.56877631834394, 251.06212109119548, 205.54147941043934, 310.63840682637556, 219.8964459357067, 180.99800133635375, 424.26199403419434, 203.77513091363411, 202.99353796101892, 183.9013423215927, 225.11187633236634, 279.4291216265116, 219.62630878514875, 184.05259108011836, 310.71021736167836, 239.6039571574715, 277.3270180509064, 368.367284459636, 315.0329207375716, 251.
_breast_cancer()
X = breast_cancer.data
y = breast_cancer.target



y_label = []

for i in y:
  if i == 0:
    y_label.append('Benign')
  else:
    y_label.append('Malignant')

CancerStatus = pd.DataFrame(y_label,columns=['CancerStatus'])

# Project the data onto the 2 primary principal components
pca = PCA(2)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2'])
X_y_df = df_scores = pd.concat([X_df, CancerStatus], axis=1)
# Out:
# Shape of X: (569, 30)
# Shape of transformed X: (569, 2)

# %%
fig = px.scatter(X_y_df, x='PC1', y='PC2',color='CancerStatus')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e40465ae-53ff-43af-8b3d-d2df1c10fe7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e40465ae-53ff-43af-8b3d-d2df1c10fe7c")) {
#                     Plotly.newPlot(
#                         'e40465ae-53ff-43af-8b3d-d2df1c10fe7c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "CancerStatus=Benign<br>PC1=%{x}<br>PC2=%{y}", "legendgroup": "CancerStatus=Benign", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "CancerStatus=Benign", "showlegend": true, "type": "scatter", "x": [2260.0138862925414, 2368.993755782055, 2095.6652015478617, 692.6905100570511, 2030.2124927427067, 888.2800535760764, 1921.0822124748456, 1074.7813350047963, 908.5784781618834, 861.5784494075682, 1404.5591306499475, 1524.232440868782, 1734.3856477464155, 1162.914003223036, 903.4301030498835, 1155.8759954206853, 1335.7294321308073, 1547.2640922523094, 2714.9647651812165, 1212.4317714296458, 2973.604428593287, 2373.6019691782813, 1734.7510811127547, 1108.4631538458432, 1777.6558385001722, 1473.5911940823262, 1553.5494014027317, 2003.8525915393657, 996.1820010503886, 1624.8165151002727, 2162.042898148666, 1504.2572468076062, 1509.9210685132373, 1019.2135180118493, 970.8981567144668, 929.6255898074818, 971.8765518106571, 637.8433048956787, 1996.8987396675013, 1065.4961111280081, 915.1639499622954, 1907.4358858823316, 933.1141290886243, 1676.2316204388826, 1257.27539152663, 2442.009878044559, 1190.8702619721466, 1164.2796987988636, 1025.5945079554199, 1145.0467422638199, 2192.2723604290954, 1928.4525110864565, 1004.3149509387931, 1479.4736991080679, 1911.2613171187575, 2046.737170519577, 3177.2772512733154, 1706.6956391482001, 1938.1073461278202, 1035.408228251566, 1954.4851114245007, 1095.1342293791079, 1250.6243498943372, 2162.0750741376783, 1046.7657597617992, 1084.7742872772858, 989.3929510475349, 2816.2905341415208, 1298.122034008101, 1502.0891824191704, 1595.7582132843522, 1893.338617399546, 2704.6697174015153, 1029.2206779318062, 1915.1954716407256, 1985.8705856740435, 1384.8194447236192, 1432.6470002172537, 1926.0034396534768, 827.4273473508026, 1193.5666553794374, 1485.3209038457535, 736.4107773770403, 1623.7480795020315, 1890.4927041353928, 2548.299671999023, 2939.2401982932474, 1546.0739882615062, 1942.2857621485778, 1150.3590200997087, 1332.3864761214795, 1278.559848260111, 3928.1127513161496, 2476.263624699254, 1490.070469744064, 1206.9295927525188, 1752.4534177150294, 975.5204464129101, 912.0405109141296, 1026.7381506788902, 1003.7088906948053, 1590.6893419475798, 2047.7445317999702, 1232.2910633080473, 1561.0891247546904, 2582.4801680911696, 1304.2899113862677, 1224.541366373823, 1512.8142354415315, 2096.9227844145767, 3466.5720201995673, 1373.5095840362374, 1017.9377267426346, 948.2494248594628, 2367.831278695035, 2762.6866605589844, 1332.4870315703436, 871.5435770189673, 1488.3756503731415, 2293.8830467141534, 3396.3513009718054, 2183.8010615532844, 1689.6681448701092, 1819.7776926960255, 2438.769763548982, 2288.404011735985, 1533.6010872887584, 2301.3088917170658, 1025.9850678371806, 2284.80182527831, 1173.228856328316, 1463.4784710041022, 1278.4778076173313, 2252.945678496413, 1533.1560834809009, 1609.5509852276148, 1245.2409957848452, 1717.1142798273752, 3684.6994549291785, 2825.9660752459868, 1654.6643723150548, 1635.7236173757892, 2073.7628631878065, 1994.290452385968, 1306.5714352033444, 704.3588638770395, 2399.1037714147155, 2109.882026334227, 1810.3251036926597, 2086.8944236818215, 2322.0838368929362, 1388.7157415339477, 1271.1967242033925, 1333.6906399768009, 1651.5273345700582, 2177.919252133153, 3404.0889055801485, 1945.818454222441, 1184.8032026660587, 3820.87221404618, 1278.3647282100508, 2202.0484055335983, 2080.3927817034482, 3504.813602697502, 2685.99960494782, 1440.1236883967872, 2039.2710333816672, 2365.7538105187978, 628.0040649259308, 1000.1015533977582, 1741.3692383414505, 1557.5585714743204, 2518.8481966703243, 1639.2704019655537, 1676.0809001860455, 1177.2209489029738, 1926.0824546531223, 1075.0055212866273, 1921.4610406489362, 1957.261493698467, 1060.750339967844, 1588.2475410276613, 1625.5782003841166, 1745.9175372601933, 2456.331252489917, 1841.2562030147403, 1903.5874241962063, 4967.0493 ...

# %%
#3-D Plotly

# data = datasets.load_digits()
breast_cancer = datasets.load_breast_cancer()
X = breast_cancer.data
y = breast_cancer.target



y_label = []

for i in y:
  if i == 0:
    y_label.append('Benign')
  else:
    y_label.append('Malignant')

CancerStatus = pd.DataFrame(y_label,columns=['CancerStatus'])

# Project the data onto the 3 primary principal components
pca = PCA(3)
pca.fit(X)
X_projected = pca.transform(X)

print("Shape of X:", X.shape)
print("Shape of transformed X:", X_projected.shape)


X_df = pd.DataFrame(X_projected,columns=['PC1','PC2','PC3'])
X_y_df = df_scores = pd.concat([X_df, CancerStatus], axis=1)
# Out:
# Shape of X: (569, 30)
# Shape of transformed X: (569, 3)

# %%
fig = px.scatter_3d(X_y_df, x='PC1', y='PC2', z='PC3',color='CancerStatus')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="34c3f7c5-7a22-4f63-9d20-fd035fea2724" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34c3f7c5-7a22-4f63-9d20-fd035fea2724")) {
#                     Plotly.newPlot(
#                         '34c3f7c5-7a22-4f63-9d20-fd035fea2724',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "CancerStatus=Benign<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}", "legendgroup": "CancerStatus=Benign", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "CancerStatus=Benign", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [2260.0138862925414, 2368.993755782055, 2095.6652015478617, 692.6905100570511, 2030.2124927427067, 888.2800535760764, 1921.0822124748456, 1074.7813350047963, 908.5784781618834, 861.5784494075682, 1404.5591306499475, 1524.232440868782, 1734.3856477464155, 1162.914003223036, 903.4301030498835, 1155.8759954206853, 1335.7294321308073, 1547.2640922523094, 2714.9647651812165, 1212.4317714296458, 2973.604428593287, 2373.6019691782813, 1734.7510811127547, 1108.4631538458432, 1777.6558385001722, 1473.5911940823262, 1553.5494014027317, 2003.8525915393657, 996.1820010503886, 1624.8165151002727, 2162.042898148666, 1504.2572